# %%
import numpy as np
import time

# %%
#execution performance
size=1000000

#python list
list1=list(range(size))
start=time.time()
sq_list=[x**2 for x in list1]
end=time.time()
print(f"Python list time ={end-start} seconds")

#numpy arrays
np_arr=np.array(list1)
start=time.time()
#vectorization
sq_arr=np_arr**2
end=time.time()
print(f"numpy array time ={end-start} seconds")
# Out:
# Python list time =0.12193489074707031 seconds
# numpy array time =0.0028634071350097656 seconds
